# %%
import csv
import json
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pprint
import os
from collections import defaultdict
from surprise import BaselineOnly, Dataset, Reader, accuracy
from surprise.model_selection import cross_validate, train_test_split

# %% [markdown]
# ## Test on sample data

# %%
from surprise import SVD
from surprise import Dataset
from surprise.model_selection import cross_validate

data = Dataset.load_builtin('ml-100k')
algo = SVD()
cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9401  0.9364  0.9341  0.9384  0.9344  0.9367  0.0023
# MAE (testset)     0.7396  0.7375  0.7373  0.7402  0.7365  0.7382  0.0014
# Fit time          0.67    0.76    0.73    0.68    0.69    0.71    0.03
# Test time         0.13    0.16    0.12    0.16    0.17    0.15    0.02
# {'test_rmse': array([0.94014999, 0.93642459, 0.93408295, 0.9383508 , 0.93443023]),
#  'test_mae': array([0.73959345, 0.73749852, 0.73735   , 0.74017302, 0.73648832]),
#  'fit_time': (0.6667459011077881,
#   0.7562968730926514,
#   0.73232102394104,
#   0.6842060089111328,
#   0.6908578872680664),
#  'test_time': (0.12873291969299316,
#   0.1616687774658203,
#   0.12313079833984375,
#   0.1630866527557373,
#   0.16676926612854004)}

# %% [markdown]
# ## Perform SVD on my data
#
# SVD predicts a user's rating of a given champion, accounting for their individual bias.

# %%
file_path = os.path.expanduser("../data/data_surprise_format.csv")
reader = Reader(sep=",", rating_scale=(0,1))
data = Dataset.load_from_file(file_path, reader)

algo = SVDpp()
res = cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
print(res['test_rmse'].mean())
# Out:
# Evaluating RMSE, MAE of algorithm SVDpp on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.1233  0.1227  0.1224  0.1247  0.1234  0.1233  0.0008
# MAE (testset)     0.0486  0.0482  0.0480  0.0485  0.0483  0.0483  0.0002
# Fit time          83.72   83.14   86.12   82.43   82.39   83.56   1.37
# Test time         22.27   22.13   21.14   20.95   21.91   21.68   0.54
# 0.12329196553356725

# %% [markdown]
# ## Observe correlation of RMSE and N Factors in SVD

# %%
file_path = os.path.expanduser("../data/data_surprise_format.csv")
reader = Reader(sep=",", rating_scale=(0,1))
data = Dataset.load_from_file(file_path, reader)

x = np.arange(2, 161, 10)
y = np.zeros_like(x, dtype=float)


for i, n in enumerate(x):
    algo = KNNBasic(n=)
    print(n)
    y[i] = cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=5, verbose=False)['test_rmse'].mean()
# Out:
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-93aa081cfb43> in <module>
#      10     algo = SVD(n_factors=n)
#      11     print(n)
# ---> 12     y[i] = cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=5, verbose=False)['test_rmse'].mean()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/surprise/model_selection/validation.py in cross_validate(algo, data, measures, cv, return_train_measures, n_jobs, pre_dispatch, verbose)
#     106         for (trainset, testset) in cv.split(data)
#     107     )
# --> 108     out = Parallel(n_jobs=n_jobs, pre_dispatch=pre_dispatch)(delayed_list)
#     109
#     110     (test_measures_dicts, train_measures_dicts, fit_times, test_times) = zip(*out)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1861             output = self._get_sequential_output(iterable)
#    1862             next(output)
# -> 1863             return output if self.return_generator else list(output)
#    1864
#    1865         # Let's create an ID that uniquely identifies the current call. If the
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in _get_sequential_output(self, iterable)
#    1790                 self.n_dispatched_batches += 1
#    1791                 self.n_dispatched_tasks += 1
# -> 1792                 res = func(*args, **kwargs)
#    1793                 self.n_completed_tasks += 1
#    1794                 self.print_progress()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/surprise/model_selection/validation.py in fit_and_score(algo, trainset, testset, measures, return_train_measures)
#     174     fit_time = time.time() - start_fit
#     175     start_test = time.time()
# --> 176     predictions = algo.test(testset)
#     177     test_time = time.time() - start_test
#     178
#
# ~/opt/anaconda3/lib/python3.8/site-packages/surprise/prediction_algorithms/algo_base.py in test(self, testset, verbose)
#     158
#     159         # The ratings are translated back to their original scale.
# --> 160         predictions = [
#     161             self.predict(uid, iid, r_ui_trans, verbose=verbose)
#     162             for (uid, iid, r_ui_trans) in testset
#
# ~/opt/anaconda3/lib/python3.8/site-packages/surprise/prediction_algorithms/algo_base.py in <listcomp>(.0)
#     159         # The ratings are translated back to their original scale.
#     160         predictions = [
# --> 161             self.predict(uid, iid, r_ui_trans, verbose=verbose)
#     162             for (uid, iid, r_ui_trans) in testset
#     163         ]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/surprise/prediction_algorithms/algo_base.py in predict(self, uid, iid, r_ui, clip, verbose)
#     116         if clip:
#     117             lower_bound, higher_bound = self.trainset.rating_scale
# --> 118             est = min(higher_bound, est)
#     119             est = max(lower_bound, est)
#     120
#
# KeyboardInterrupt:

# %%
plt.plot(x,y)

# %% [markdown]
# ## K-NN testing

# %%
file_path = os.path.expanduser("../data/data_surprise_format.csv")
reader = Reader(sep=",", rating_scale=(0,1))
data = Dataset.load_from_file(file_path, reader)

x = np.arange(5, 40, 5)
y = np.zeros_like(x, dtype=float)

for i, n in enumerate(x):
    algo = KNNBasic(k=n)
    y[i] = cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=5, verbose=False)['test_rmse'].mean()
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
plt.plot(x,y)

# %% [markdown]
# ## Test available classifiers on champion data
#
# SVD - predict a user's rating of a given champion, accounting for their individual bias.
#
# SVD++ - extension of SVD, accounting for implicit ratings, which accounts for the fact that a user rated item j without accouting for the given value (the user looked at this value)
#
# Baseline - predicts baseline estimate for given user and item
#
# Random - give a random rating based on distribution of training set
#
# NMF - based on Non-negative Matrix Factorization, similar to SVD - algorithm highly dependent on initial values
#
# Slope One - predict users preference for particular item based on preferences of other users
#
# Co-clustering - users and items assigned clusters
#
# k-NN Basic - aggregate of neighbors
#
# Centered k-NN - aggregate of neighbors, but the mean rating of each user is accounted for
#
# k-NN baseline - k-nn, but a baseline rating is accounted for

# %%
from surprise import SVD, SVDpp, BaselineOnly, NormalPredictor, NMF, SlopeOne, CoClustering, KNNBasic, KNNWithMeans, KNNBaseline

sim_options = {
    "name": "cosine",
    "user_based": False
}

classifiers = [BaselineOnly(), SVD(), SVDpp(), NormalPredictor(), NMF(), SlopeOne(), CoClustering(n_cltr_u = 3, n_cltr_i = 3), KNNBasic(sim_options=sim_options), KNNWithMeans(sim_options=sim_options), KNNBaseline(sim_options=sim_options)]
labels = ['Baseline', 'SVD', 'SVDpp', 'Random', 'NMF', 'Slope One', 'Co-clustering', 'KNN', 'KNN With Means','KNN Baseline']



results = {}
for (cls, tag) in zip(classifiers, labels):
    results[tag] = cross_validate(cls, data, measures=['RMSE', 'MAE'], cv=5, verbose=False)['test_rmse'].mean()
# Out:
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-e3b66e368f40> in <module>
#      13 results = {}
#      14 for (cls, tag) in zip(classifiers, labels):
# ---> 15     results[tag] = cross_validate(cls, data, measures=['RMSE', 'MAE'], cv=5, verbose=False)['test_rmse'].mean()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/surprise/model_selection/validation.py in cross_validate(algo, data, measures, cv, return_train_measures, n_jobs, pre_dispatch, verbose)
#     106         for (trainset, testset) in cv.split(data)
#     107     )
# --> 108     out = Parallel(n_jobs=n_jobs, pre_dispatch=pre_dispatch)(delayed_list)
#     109
#     110     (test_measures_dicts, train_measures_dicts, fit_times, test_times) = zip(*out)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1861             output = self._get_sequential_output(iterable)
#    1862             next(output)
# -> 1863             return output if self.return_generator else list(output)
#    1864
#    1865         # Let's create an ID that uniquely identifies the current call. If the
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in _get_sequential_output(self, iterable)
#    1790                 self.n_dispatched_batches += 1
#    1791                 self.n_dispatched_tasks += 1
# -> 1792                 res = func(*args, **kwargs)
#    1793                 self.n_completed_tasks += 1
#    1794                 self.print_progress()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/surprise/model_selection/validation.py in fit_and_score(algo, trainset, testset, measures, return_train_measures)
#     171
#     172     start_fit = time.time()
# --> 173     algo.fit(trainset)
#     174     fit_time = time.time() - start_fit
#     175     start_test = time.time()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/surprise/prediction_algorithms/matrix_factorization.pyx in surprise.prediction_algorithms.matrix_factorization.SVD.fit()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/surprise/prediction_algorithms/matrix_factorization.pyx in surprise.prediction_algorithms.matrix_factorization.SVD.sgd()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/surprise/trainset.py in all_ratings(self)
#     192         for u, u_ratings in self.ur.items():
#     193             for i, r in u_ratings:
# --> 194                 yield u, i, r
#     195
#     196     def build_testset(self):
#
# KeyboardInterrupt:

# %%
pprint.pprint(results)
# Out:
# {'Baseline': 0.22363299006516155,
#  'Co-clustering': 0.32352320231927884,
#  'KNN': 0.22545000251859332,
#  'KNN Baseline': 0.2222623130717511,
#  'KNN With Means': 0.22252512409399589,
#  'NMF': 0.22898081895054573,
#  'Random': 0.3255606065930174,
#  'SVD': 0.2238397484798468,
#  'SVDpp': 0.22213030261048144,
#  'Slope One': 0.22264023233177382}

# %% [markdown]
# ## Paramaterize for SVDpp

# %%
filename = '../data/champion.json'
with open(filename, 'r') as f:
    champ_data = json.load(f)

# contains index of championId and name
id_champ_map = {}
cols = []
for i, c in enumerate(champ_data['data'].keys()):
    id_champ_map[int(champ_data['data'][c]['key'])] = {'champion': champ_data['data'][c]['id'], 'index': i}
    cols.append(champ_data['data'][c]['id'])

# %%
filename = '../data/data_surprise_format.csv'
most_played = {}

with open(filename, 'r') as f:
    reader_obj = csv.reader(f)
    cur_id = ''
    most = []
    for row in reader_obj:
        if cur_id != row[0]:
            count = 0
            if cur_id != '':
                most_played[cur_id] = most
                most = []
            cur_id = row[0]
        #if count < 5:
        most.append((row[1], float(row[2])))
        count += 1
        #else:
            #continue

# %%
top_5 = os.path.expanduser("../data/top_5_surprise.csv")
top_25 = os.path.expanduser("../data/top_25_surprise.csv")
all_champs = os.path.expanduser('../data/all_champs_surprise.csv')
file_path = all_champs
reader = Reader(sep=",", rating_scale=(0,1))
data = Dataset.load_from_file(file_path, reader)

sim_options = {
    "name": "pearson_baseline",
    "user_based": False
}

trainset = data.build_full_trainset()
algo = KNNBasic(sim_options=sim_options)

algo.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
mean_rating = {}

for rating in trainset.all_ratings():
    __, iid, rate = rating
    iid = trainset.to_raw_iid(iid)
    if iid not in mean_rating.keys():
        mean_rating[iid] = {'score': rate, 'n': 1, 'mean': rate}
    else:
        mean_rating[iid]['score'] += rate
        mean_rating[iid]['n'] += 1
        mean_rating[iid]['mean'] = mean_rating[iid]['score']/mean_rating[iid]['n']

# %%
pprint.pprint(mean_rating)
# Out:
# {'Aatrox': {'mean': 0.036715657673944344,
#             'n': 5327,
#             'score': 195.58430842910153},
#  'Ahri': {'mean': 0.04527005401008929, 'n': 5327, 'score': 241.15357771174564},
#  'Akali': {'mean': 0.07550952601280488, 'n': 5327, 'score': 402.2392450702116},
#  'Akshan': {'mean': 0.008462710047927579,
#             'n': 5327,
#             'score': 45.08085642531021},
#  'Alistar': {'mean': 0.011503995426546445,
#              'n': 5327,
#              'score': 61.28178363721291},
#  'Amumu': {'mean': 0.020119887665374495,
#            'n': 5327,
#            'score': 107.17864159344992},
#  'Anivia': {'mean': 0.007786215934048973,
#             'n': 5327,
#             'score': 41.47717228067888},
#  'Annie': {'mean': 0.01424368614996099, 'n': 5327, 'score': 75.8761161208422},
#  'Aphelios': {'mean': 0.025268072857279455,
#               'n': 5327,
#               'score': 134.60302411072766},
#  'Ashe': {'mean': 0.06830658960804423, 'n': 5327, 'score': 363.8692028420516},
#  'AurelionSol': {'mean': 0.008983120703282454,
#                  'n': 5327,
#                  'score': 47.85308398638563},
#  'Azir': {'mean': 0.009914937445013176, 'n': 5327, 'score': 52.81687176958519},
#  'Bard': {'mean': 0.010733514144592367, 'n': 5327, 'score': 57.17742984824354},
#  'Belveth': {'mean': 0.003401338911129849,
#              'n': 5327,
#              'score': 18.118932379588706},
#  'Blitzcrank': {'mean': 0.030752519615610756,
#                 'n': 5327,
#                 'score': 163.8186719923585},
#  'Brand': {'mean': 0.03616104492406165, 'n': 5327, 'score': 192.6298863104764},
#  'Braum': {'mean': 0.004925166657733628,
#            'n': 5327,
#            'score': 26.236362785747037},
#  'Briar': {'mean': 0.002126113310459607,
#            'n': 5327,
#            'score': 11.325805604818326},
#  'Caitlyn': {'mean': 0.08027509477658307, 'n': 5327, 'score': 427.625429874858},
#  'Camille': {'mean': 0.0233892402064113,
#              'n': 5327,
#              'score': 124.59448257955299},
#  'Cassiopeia': {'mean': 0.008216461453316136,
#                 'n': 5327,
#                 'score': 43.76909016181506},
#  'Chogath': {'mean': 0.020694494228392864,
#              'n': 5327,
#              'score': 110.23957075464878},
#  'Corki': {'mean': 0.004207237291095747,
#            'n': 5327,
#            'score': 22.411953049667044},
#  'Darius': {'mean': 0.05619877188840635,
#             'n': 5327,
#             'score': 299.37085784954064},
#  'Diana': {'mean': 0.030840466929408283,
#            'n': 5327,
#            'score': 164.28716733295792},
#  'DrMundo': {'mean': 0.016651155201733558,
#              'n': 5327,
#              'score': 88.70070375963466},
#  'Draven': {'mean': 0.0324098909049713, 'n': 5327, 'score': 172.64748885078214},
#  'Ekko': {'mean': 0.04997066748403262, 'n': 5327, 'score': 266.1937456874418},
#  'Elise': {'mean': 0.007337334890475806, 'n': 5327, 'score': 39.08598296156462},
#  'Evelynn': {'mean': 0.02019510127449403,
#              'n': 5327,
#              'score': 107.57930448922971},
#  'Ezreal': {'mean': 0.10576101340720452, 'n': 5327, 'score': 563.3889184201785},
#  'Fiddlesticks': {'mean': 0.014059336479745797,
#                   'n': 5327,
#                   'score': 74.89408542760586},
#  'Fiora': {'mean': 0.030778899102201832,
#            'n': 5327,
#            'score': 163.95919551742915},
#  'Fizz': {'mean': 0.024823964360946048, 'n': 5327, 'score': 132.2372581507596},
#  'Galio': {'mean': 0.016312390357704532, 'n': 5327, 'score': 86.89610343549205},
#  'Gangplank': {'mean': 0.027443739464132606,
#                'n': 5327,
#                'score': 146.1928001254344},
#  'Garen': {'mean': 0.055917514426267745, 'n': 5327, 'score': 297.8725993487283},
#  'Gnar': {'mean': 0.007728418590936956, 'n': 5327, 'score': 41.169285833921165},
#  'Gragas': {'mean': 0.011617086506318281,
#             'n': 5327,
#             'score': 61.88421981915749},
#  'Graves': {'mean': 0.04483037176944647,
#             'n': 5327,
#             'score': 238.81139041584134},
#  'Gwen': {'mean': 0.005945985265589442, 'n': 5327, 'score': 31.674263509794958},
#  'Hecarim': {'mean': 0.02013779521555899,
#              'n': 5327,
#              'score': 107.27403511328274},
#  'Heimerdinger': {'mean': 0.012589427274762099,
#                   'n': 5327,
#                   'score': 67.0638790926577},
#  'Illaoi': {'mean': 0.01811671101108024, 'n': 5327, 'score': 96.50771955602445},
#  'Irelia': {'mean': 0.05268854854493618,
#             'n': 5327,
#             'score': 280.67189809887503},
#  'Ivern': {'mean': 0.0063043952663410395,
#            'n': 5327,
#            'score': 33.58351358379872},
#  'Janna': {'mean': 0.01577770387254079, 'n': 5327, 'score': 84.04782852902478},
#  'JarvanIV': {'mean': 0.01604427676096486,
#               'n': 5327,
#               'score': 85.4678623056598},
#  'Jax': {'mean': 0.043017645309109495, 'n': 5327, 'score': 229.15499656162626},
#  'Jayce': {'mean': 0.01218666614941967, 'n': 5327, 'score': 64.91837057795858},
#  'Jhin': {'mean': 0.0946362242812791, 'n': 5327, 'score': 504.1271667463738},
#  'Jinx': {'mean': 0.04486225751182756, 'n': 5327, 'score': 238.9812457655054},
#  'KSante': {'mean': 0.0026241415451828867,
#             'n': 5327,
#             'score': 13.978802011189238},
#  'Kaisa': {'mean': 0.09561008016142365, 'n': 5327, 'score': 509.3148970199038},
#  'Kalista': {'mean': 0.006066099250231586,
#              'n': 5327,
#              'score': 32.31411070598366},
#  'Karma': {'mean': 0.013881945131058126, 'n': 5327, 'score': 73.94912171314664},
#  'Karthus': {'mean': 0.009187097102555416,
#              'n': 5327,
#              'score': 48.939666265312695},
#  'Kassadin': {'mean': 0.00994698607162802,
#               'n': 5327,
#               'score': 52.98759480356246},
#  'Katarina': {'mean': 0.04744767076254284,
#               'n': 5327,
#               'score': 252.7537421520657},
#  'Kayle': {'mean': 0.026698374484619924,
#            'n': 5327,
#            'score': 142.22224087957034},
#  'Kayn': {'mean': 0.07310301961763221, 'n': 5327, 'score': 389.41978550312683},
#  'Kennen': {'mean': 0.00608653533930385, 'n': 5327, 'score': 32.42297375247161},
#  'Khazix': {'mean': 0.0336262738415365, 'n': 5327, 'score': 179.12716075386493},
#  'Kindred': {'mean': 0.014321899281996052,
#              'n': 5327,
#              'score': 76.29275747519297},
#  'Kled': {'mean': 0.008472728380307895, 'n': 5327, 'score': 45.13422408190016},
#  'KogMaw': {'mean': 0.008478716072548477,
#             'n': 5327,
#             'score': 45.16612051846573},
#  'Leblanc': {'mean': 0.021275249054455072,
#              'n': 5327,
#              'score': 113.33325171308216},
#  'LeeSin': {'mean': 0.05142699927442214, 'n': 5327, 'score': 273.9516251348467},
#  'Leona': {'mean': 0.02257569389155332, 'n': 5327, 'score': 120.26072136030454},
#  'Lillia': {'mean': 0.015621874811030749, 'n': 5327, 'score': 83.2177271183608},
#  'Lissandra': {'mean': 0.005444048392661722,
#                'n': 5327,
#                'score': 29.00044578770899},
#  'Lucian': {'mean': 0.04552018719810541, 'n': 5327, 'score': 242.4860372043075},
#  'Lulu': {'mean': 0.016108951700190798, 'n': 5327, 'score': 85.81238570691639},
#  'Lux': {'mean': 0.11029588882770833, 'n': 5327, 'score': 587.5461997852022},
#  'Malphite': {'mean': 0.030971969888287303,
#               'n': 5327,
#               'score': 164.98768359490646},
#  'Malzahar': {'mean': 0.013524713616354054,
#               'n': 5327,
#               'score': 72.04614943431804},
#  'Maokai': {'mean': 0.009878424816747389,
#             'n': 5327,
#             'score': 52.62236899881334},
#  'MasterYi': {'mean': 0.053355393062574946,
#               'n': 5327,
#               'score': 284.22417884433673},
#  'Milio': {'mean': 0.0010452993064683062,
#            'n': 5327,
#            'score': 5.568309405556667},
#  'MissFortune': {'mean': 0.06856194250645589,
#                  'n': 5327,
#                  'score': 365.2294677318905},
#  'MonkeyKing': {'mean': 0.017907284767011703,
#                 'n': 5327,
#                 'score': 95.39210595387135},
#  'Mordekaiser': {'mean': 0.05373520102392269,
#                  'n': 5327,
#                  'score': 286.24741585443616},
#  'Morgana': {'mean': 0.0487136260666288, 'n': 5327, 'score': 259.4974860569316},
#  'Naafiri': {'mean': 0.0009994426080183305,
#              'n': 5327,
#              'score': 5.3240307729136465},
#  'Nami': {'mean': 0.020406172233845707, 'n': 5327, 'score': 108.70367948969609},
#  'Nasus': {'mean': 0.03378481057946, 'n': 5327, 'score': 179.9716859567834},
#  'Nautilus': {'mean': 0.029741046588470446,
#               'n': 5327,
#               'score': 158.43055517678206},
#  'Neeko': {'mean': 0.024560889669840266, 'n': 5327, 'score': 130.8358592712391},
#  'Nidalee': {'mean': 0.009933869646173788,
#              'n': 5327,
#              'score': 52.917723605167765},
#  'Nilah': {'mean': 0.0017519172161943367,
#            'n': 5327,
#            'score': 9.332463010667231},
#  'Nocturne': {'mean': 0.015649567382635687,
#               'n': 5327,
#               'score': 83.3652454473003},
#  'Nunu': {'mean': 0.027037246008419197, 'n': 5327, 'score': 144.02740948684905},
#  'Olaf': {'mean': 0.013187873100482254, 'n': 5327, 'score': 70.25180000626897},
#  'Orianna': {'mean': 0.01092379618107217,
#              'n': 5327,
#              'score': 58.19106225657145},
#  'Ornn': {'mean': 0.01724947572708851, 'n': 5327, 'score': 91.8879571982005},
#  'Pantheon': {'mean': 0.03815955463221181,
#               'n': 5327,
#               'score': 203.2759475257923},
#  'Poppy': {'mean': 0.00976873030286424, 'n': 5327, 'score': 52.038026323357805},
#  'Pyke': {'mean': 0.06067475354204809, 'n': 5327, 'score': 323.2144121184902},
#  'Qiyana': {'mean': 0.01870397317400764, 'n': 5327, 'score': 99.6360650979387},
#  'Quinn': {'mean': 0.008820581466341473, 'n': 5327, 'score': 46.98723747120103},
#  'Rakan': {'mean': 0.014803251129602705, 'n': 5327, 'score': 78.85691876739361},
#  'Rammus': {'mean': 0.00899706307106252,
#             'n': 5327,
#             'score': 47.927354979550046},
#  'RekSai': {'mean': 0.0058458683275668145,
#             'n': 5327,
#             'score': 31.14094058094842},
#  'Rell': {'mean': 0.004125528622450877, 'n': 5327, 'score': 21.976690971795822},
#  'Renata': {'mean': 0.0026278556740505464,
#             'n': 5327,
#             'score': 13.99858717566726},
#  'Renekton': {'mean': 0.023331128999439284,
#               'n': 5327,
#               'score': 124.28492418001306},
#  'Rengar': {'mean': 0.02731661092191214,
#             'n': 5327,
#             'score': 145.51558638102597},
#  'Riven': {'mean': 0.03421253100629825, 'n': 5327, 'score': 182.2501526705508},
#  'Rumble': {'mean': 0.0061031790355023895,
#             'n': 5327,
#             'score': 32.51163472212123},
#  'Ryze': {'mean': 0.020252592055845394, 'n': 5327, 'score': 107.88555788148841},
#  'Samira': {'mean': 0.02858467540373653, 'n': 5327, 'score': 152.2705658757045},
#  'Sejuani': {'mean': 0.008489483224959835,
#              'n': 5327,
#              'score': 45.22347713936104},
#  'Senna': {'mean': 0.049757715246437684,
#            'n': 5327,
#            'score': 265.05934911777354},
#  'Seraphine': {'mean': 0.017565761537609092,
#                'n': 5327,
#                'score': 93.57281171084362},
#  'Sett': {'mean': 0.047927225937987, 'n': 5327, 'score': 255.30833257165673},
#  'Shaco': {'mean': 0.03527837786223616, 'n': 5327, 'score': 187.927918872132},
#  'Shen': {'mean': 0.019321516873222574, 'n': 5327, 'score': 102.92572038365665},
#  'Shyvana': {'mean': 0.011293925553098359,
#              'n': 5327,
#              'score': 60.16274142135496},
#  'Singed': {'mean': 0.011623003142630631,
#             'n': 5327,
#             'score': 61.915737740793375},
#  'Sion': {'mean': 0.0290866853708254, 'n': 5327, 'score': 154.9447729703869},
#  'Sivir': {'mean': 0.02121639427639085, 'n': 5327, 'score': 113.01973231033406},
#  'Skarner': {'mean': 0.0019975022706686966,
#              'n': 5327,
#              'score': 10.640694595852148},
#  'Sona': {'mean': 0.01855217531113986, 'n': 5327, 'score': 98.82743788244204},
#  'Soraka': {'mean': 0.027975291218045723,
#             'n': 5327,
#             'score': 149.02437631852956},
#  'Swain': {'mean': 0.03052738054132727, 'n': 5327, 'score': 162.61935614365038},
#  'Sylas': {'mean': 0.04497721440218998, 'n': 5327, 'score': 239.593621120466},
#  'Syndra': {'mean': 0.01434065290395008, 'n': 5327, 'score': 76.39265801934208},
#  'TahmKench': {'mean': 0.012195890834837419,
#                'n': 5327,
#                'score': 64.96751047717893},
#  'Taliyah': {'mean': 0.0064925520775503094,
#              'n': 5327,
#              'score': 34.5858249171105},
#  'Talon': {'mean': 0.030264103668502712,
#            'n': 5327,
#            'score': 161.21688024211394},
#  'Taric': {'mean': 0.005614650162272336,
#            'n': 5327,
#            'score': 29.909241414424734},
#  'Teemo': {'mean': 0.04551250022822247, 'n': 5327, 'score': 242.44508871574112},
#  'Thresh': {'mean': 0.05074031689761215,
#             'n': 5327,
#             'score': 270.29366811357994},
#  'Tristana': {'mean': 0.03643931256051255,
#               'n': 5327,
#               'score': 194.11221800985035},
#  'Trundle': {'mean': 0.009410272094154697,
#              'n': 5327,
#              'score': 50.12851944556207},
#  'Tryndamere': {'mean': 0.023985579650385853,
#                 'n': 5327,
#                 'score': 127.77118279760543},
#  'TwistedFate': {'mean': 0.013302894841527255,
#                  'n': 5327,
#                  'score': 70.86452082081568},
#  'Twitch': {'mean': 0.0412851095279429, 'n': 5327, 'score': 219.9257784553518},
#  'Udyr': {'mean': 0.019905904857039823, 'n': 5327, 'score': 106.03875517345114},
#  'Urgot': {'mean': 0.019559721687843517,
#            'n': 5327,
#            'score': 104.19463743114241},
#  'Varus': {'mean': 0.020029150373137218,
#            'n': 5327,
#            'score': 106.69528403770197},
#  'Vayne': {'mean': 0.0583710304191306, 'n': 5327, 'score': 310.9424790427087},
#  'Veigar': {'mean': 0.041166347684514284,
#             'n': 5327,
#             'score': 219.2931341154076},
#  'Velkoz': {'mean': 0.014335191863217175,
#             'n': 5327,
#             'score': 76.36356705535789},
#  'Vex': {'mean': 0.006675003098348265, 'n': 5327, 'score': 35.55774150490121},
#  'Vi': {'mean': 0.01677986405038845, 'n': 5327, 'score': 89.38633579641926},
#  'Viego': {'mean': 0.025238639319754202,
#            'n': 5327,
#            'score': 134.44623165633064},
#  'Viktor': {'mean': 0.0172016170227229, 'n': 5327, 'score': 91.63301388004489},
#  'Vladimir': {'mean': 0.02922925487845665,
#               'n': 5327,
#               'score': 155.70424073753858},
#  'Volibear': {'mean': 0.029907009905783287,
#               'n': 5327,
#               'score': 159.31464176810758},
#  'Warwick': {'mean': 0.03526126736992844,
#              'n': 5327,
#              'score': 187.8367712796088},
#  'Xayah': {'mean': 0.027680532871655412,
#            'n': 5327,
#            'score': 147.45419860730837},
#  'Xerath': {'mean': 0.02736394345371461,
#             'n': 5327,
#             'score': 145.76772677793772},
#  'XinZhao': {'mean': 0.015230349358081981,
#              'n': 5327,
#              'score': 81.13207103050271},
#  'Yasuo': {'mean': 0.1362513397227868, 'n': 5327, 'score': 725.8108867032853},
#  'Yone': {'mean': 0.04434331914315133, 'n': 5327, 'score': 236.21686107556715},
#  'Yorick': {'mean': 0.015612450522251261,
#             'n': 5327,
#             'score': 83.16752393203247},
#  'Yuumi': {'mean': 0.030830054019164957,
#            'n': 5327,
#            'score': 164.23169776009172},
#  'Zac': {'mean': 0.012473576243099587, 'n': 5327, 'score': 66.4467406469915},
#  'Zed': {'mean': 0.05903560246732461, 'n': 5327, 'score': 314.4826543434382},
#  'Zeri': {'mean': 0.007839686549355063, 'n': 5327, 'score': 41.76201024841442},
#  'Ziggs': {'mean': 0.007893508957660895, 'n': 5327, 'score': 42.04872221745959},
#  'Zilean': {'mean': 0.008697202172067264,
#             'n': 5327,
#             'score': 46.32999597060232},
#  'Zoe': {'mean': 0.019731878241109623, 'n': 5327, 'score': 105.11171539039096},
#  'Zyra': {'mean': 0.016516452723314822, 'n': 5327, 'score': 87.98314365709805}}

# %%
# Out:
# Prediction(uid='jBZi44QpCh3Ziwz30Na4rG3hT4f3dS0V7PanMs9qM_xXZTzZ', iid='Yasuo', r_ui=0.24, est=0.5127884837789994, details={'actual_k': 6, 'was_impossible': False})

# %%
def printRecommendations(algo, trainset, n=10):
    def get_top_n(predictions, n):
        top_n = defaultdict(list)
        for uid, iid, true_r, est, _ in predictions:
            top_n[uid].append((iid,est))
            #top_n[uid].append((iid,est/mean_rating[iid]['mean']))

        for uid, user_ratings in top_n.items():
            user_ratings.sort(key=lambda x: x[1], reverse=True)
            top_n[uid] = user_ratings[:n]

        return top_n

    testset = trainset.build_anti_testset(fill=0)
    predictions = algo.test(testset)

    rec = get_top_n(predictions, n)
    
    test_IDS = ['jBZi44QpCh3Ziwz30Na4rG3hT4f3dS0V7PanMs9qM_xXZTzZ', 'XmkVHqwlmKUd1JRuaWL6SshQYaIUn3-oWBDRaQDFlTQymrMG', 'h5D-yYexQgcqENJKCwm1VGjWkTdGCOz8ff2YIOB7b-VFCDvE', 'AqRWUr3C46RW6tNpOfmItiNc1fTI8ma5sBpkfJLo45kaZXEc', 'HpXI4tMjKDx3ySSN0fXBYBh3zqtvEW2xDgQG6eKyamQN9k9F', 'Ovy0KZGs2bdtLi3fddWlzRFJnQ-3KP2iIuu-1ot78uavttEw']
    for i in test_IDS:
        #pprint.pprint(most_played[i])
        print(f'Most played: {i}')
        pprint.pprint(most_played[i])
        print(f'Recommendation: {i}')
        pprint.pprint(rec[i])
        print()

# %%
printRecommendations(algo, trainset, 5)
# Out:
# Most played: jBZi44QpCh3Ziwz30Na4rG3hT4f3dS0V7PanMs9qM_xXZTzZ
# [('Ezreal', 1.0),
#  ('Jhin', 0.6567971558403671),
#  ('Ashe', 0.2896820098991787),
#  ('Kaisa', 0.24264360484377395),
#  ('Varus', 0.1900276405638873),
#  ('Zeri', 0.1846528117722101)]
# Recommendation: jBZi44QpCh3Ziwz30Na4rG3hT4f3dS0V7PanMs9qM_xXZTzZ
# [('Rengar', 0.6925089498212654),
#  ('Taric', 0.680603263365949),
#  ('Ivern', 0.6511127130002501),
#  ('Shaco', 0.6098252488636544),
#  ('Renata', 0.5984573033530298)]
#
# Most played: XmkVHqwlmKUd1JRuaWL6SshQYaIUn3-oWBDRaQDFlTQymrMG
# [('Talon', 1.0),
#  ('MasterYi', 0.37431040564373896),
#  ('XinZhao', 0.2124620811287478),
#  ('Jayce', 0.18540388007054673),
#  ('Ekko', 0.1792063492063492),
#  ('Jax', 0.1617636684303351)]
# Recommendation: XmkVHqwlmKUd1JRuaWL6SshQYaIUn3-oWBDRaQDFlTQymrMG
# [('Taric', 1),
#  ('Janna', 0.9646419528612356),
#  ('Zyra', 0.7804916207346118),
#  ('Milio', 0.69224200369963),
#  ('Renata', 0.6734997619261034)]
#
# Most played: h5D-yYexQgcqENJKCwm1VGjWkTdGCOz8ff2YIOB7b-VFCDvE
# [('Lux', 1.0),
#  ('Janna', 0.98324118021236),
#  ('Neeko', 0.9553310172725938),
#  ('Soraka', 0.8065126975583501),
#  ('Ahri', 0.606703527915056),
#  ('Morgana', 0.5522581592210207)]
# Recommendation: h5D-yYexQgcqENJKCwm1VGjWkTdGCOz8ff2YIOB7b-VFCDvE
# [('Syndra', 1), ('Galio', 1), ('Kindred', 1), ('Khazix', 1), ('Shaco', 1)]
#
# Most played: AqRWUr3C46RW6tNpOfmItiNc1fTI8ma5sBpkfJLo45kaZXEc
# [('Warwick', 1.0),
#  ('Sejuani', 0.1583087094236942),
#  ('Khazix', 0.1420356710103952),
#  ('Kaisa', 0.1393465274972896),
#  ('Graves', 0.12315852128993857),
#  ('Caitlyn', 0.11873684658064242)]
# Recommendation: AqRWUr3C46RW6tNpOfmItiNc1fTI8ma5sBpkfJLo45kaZXEc
# [('Naafiri', 0.5687703278666355),
#  ('Braum', 0.3928758992218011),
#  ('Azir', 0.32240554775915636),
#  ('Camille', 0.30231835456859946),
#  ('Shaco', 0.3005208483465971)]
#
# Most played: HpXI4tMjKDx3ySSN0fXBYBh3zqtvEW2xDgQG6eKyamQN9k9F
# [('Brand', 1.0),
#  ('Lux', 0.44281657681386066),
#  ('Veigar', 0.4026091608708177),
#  ('Morgana', 0.24119067894531906),
#  ('Neeko', 0.20571280236287026),
#  ('Galio', 0.13886927920427242)]
# Recommendation: HpXI4tMjKDx3ySSN0fXBYBh3zqtvEW2xDgQG6eKyamQN9k9F
# [('Briar', 0.9357284016589853),
#  ('Kalista', 0.9070908741205279),
#  ('Ivern', 0.878474542550891),
#  ('KogMaw', 0.7965509909275941),
#  ('TwistedFate', 0.7864221311352801)]
#
# Most played: Ovy0KZGs2bdtLi3fddWlzRFJnQ-3KP2iIuu-1ot78uavttEw
# [('MissFortune', 1.0),
#  ('Ashe', 0.4907798910774882),
#  ('Jhin', 0.1734411754595322),
#  ('Jinx', 0.09594151512621686),
#  ('Samira', 0.05067826935322552),
#  ('Sivir', 0.0481115350806115)]
# Recommendation: Ovy0KZGs2bdtLi3fddWlzRFJnQ-3KP2iIuu-1ot78uavttEw
# [('KSante', 0.7768454622551811),
#  ('Rumble', 0.7564858363900171),
#  ('Milio', 0.743241737065583),
#  ('Azir', 0.6903006505709619),
#  ('Briar', 0.6288568988884364)]

# %%
def printRec(cols, algo, n=10):
    def get_top_n(uid, cols, n):
        top_n = defaultdict(list)
        for champ in cols:
            top_n[uid].append((champ,algo.predict(uid, champ).est))
            #top_n[uid].append((champ,algo.predict(uid, champ).est/mean_rating[iid]['mean']))

        for uid, user_ratings in top_n.items():
            user_ratings.sort(key=lambda x: x[1], reverse=True)
            top_n[uid] = user_ratings[:n]

        return top_n[uid]
    
    test_IDS = ['jBZi44QpCh3Ziwz30Na4rG3hT4f3dS0V7PanMs9qM_xXZTzZ', 'XmkVHqwlmKUd1JRuaWL6SshQYaIUn3-oWBDRaQDFlTQymrMG', 'h5D-yYexQgcqENJKCwm1VGjWkTdGCOz8ff2YIOB7b-VFCDvE', 'AqRWUr3C46RW6tNpOfmItiNc1fTI8ma5sBpkfJLo45kaZXEc', 'HpXI4tMjKDx3ySSN0fXBYBh3zqtvEW2xDgQG6eKyamQN9k9F', 'Ovy0KZGs2bdtLi3fddWlzRFJnQ-3KP2iIuu-1ot78uavttEw']
    for i in test_IDS:
        #pprint.pprint(most_played[i])
        print(f'Most played: {i}')
        pprint.pprint(most_played[i])
        print(f'Recommendation: {i}')
        pprint.pprint(get_top_n(i, cols, n))
        print()

# %%
printRec(cols, algo)
# Out:
# Most played: jBZi44QpCh3Ziwz30Na4rG3hT4f3dS0V7PanMs9qM_xXZTzZ
# [('Ezreal', 1.0),
#  ('Jhin', 0.6567971558403671),
#  ('Ashe', 0.2896820098991787),
#  ('Kaisa', 0.24264360484377395),
#  ('Varus', 0.1900276405638873),
#  ('Zeri', 0.1846528117722101)]
# Recommendation: jBZi44QpCh3Ziwz30Na4rG3hT4f3dS0V7PanMs9qM_xXZTzZ
# [('Ezreal', 0.2938200848719322),
#  ('Jhin', 0.28785258856059637),
#  ('Kaisa', 0.18025362939445716),
#  ('Varus', 0.17261098424113003),
#  ('Ashe', 0.17059532906360686),
#  ('Caitlyn', 0.15784738328972747),
#  ('Jinx', 0.14665423485097717),
#  ('Aphelios', 0.13944581561516972),
#  ('Lucian', 0.12087388514021655),
#  ('Samira', 0.1193131716898805)]
#
# Most played: XmkVHqwlmKUd1JRuaWL6SshQYaIUn3-oWBDRaQDFlTQymrMG
# [('Talon', 1.0),
#  ('MasterYi', 0.37431040564373896),
#  ('XinZhao', 0.2124620811287478),
#  ('Jayce', 0.18540388007054673),
#  ('Ekko', 0.1792063492063492),
#  ('Jax', 0.1617636684303351)]
# Recommendation: XmkVHqwlmKUd1JRuaWL6SshQYaIUn3-oWBDRaQDFlTQymrMG
# [('Talon', 0.41228668174446126),
#  ('MasterYi', 0.1603549892235661),
#  ('Fizz', 0.1315119005942118),
#  ('Ekko', 0.11935664760394481),
#  ('XinZhao', 0.10043259641290232),
#  ('Fiora', 0.09756837783975242),
#  ('Jax', 0.09622284463437707),
#  ('Kayn', 0.0938785791362929),
#  ('Darius', 0.08757170160288977),
#  ('Aatrox', 0.08360444274030779)]
#
# Most played: h5D-yYexQgcqENJKCwm1VGjWkTdGCOz8ff2YIOB7b-VFCDvE
# [('Lux', 1.0),
#  ('Janna', 0.98324118021236),
#  ('Neeko', 0.9553310172725938),
#  ('Soraka', 0.8065126975583501),
#  ('Ahri', 0.606703527915056),
#  ('Morgana', 0.5522581592210207)]
# Recommendation: h5D-yYexQgcqENJKCwm1VGjWkTdGCOz8ff2YIOB7b-VFCDvE
# [('Lux', 0.44955814984204395),
#  ('Neeko', 0.4403300914273308),
#  ('Ahri', 0.4093434835084857),
#  ('Janna', 0.4047346843197492),
#  ('Soraka', 0.3887634193261132),
#  ('Morgana', 0.35868225484398836),
#  ('Nami', 0.34389677907054783),
#  ('Sona', 0.3285335217773374),
#  ('Seraphine', 0.3251655597033126),
#  ('MissFortune', 0.28595621637602636)]
#
# Most played: AqRWUr3C46RW6tNpOfmItiNc1fTI8ma5sBpkfJLo45kaZXEc
# [('Warwick', 1.0),
#  ('Sejuani', 0.1583087094236942),
#  ('Khazix', 0.1420356710103952),
#  ('Kaisa', 0.1393465274972896),
#  ('Graves', 0.12315852128993857),
#  ('Caitlyn', 0.11873684658064242)]
# Recommendation: AqRWUr3C46RW6tNpOfmItiNc1fTI8ma5sBpkfJLo45kaZXEc
# [('Warwick', 0.3097425641444172),
#  ('XinZhao', 0.07066692049309738),
#  ('Sejuani', 0.0682028608939235),
#  ('Hecarim', 0.06776722543134037),
#  ('Khazix', 0.05996560212740324),
#  ('Vi', 0.05601825191887744),
#  ('Graves', 0.04783829032403267),
#  ('Nunu', 0.0476587869090624),
#  ('Viego', 0.04629796814232083),
#  ('Shyvana', 0.044854396409078456)]
#
# Most played: HpXI4tMjKDx3ySSN0fXBYBh3zqtvEW2xDgQG6eKyamQN9k9F
# [('Brand', 1.0),
#  ('Lux', 0.44281657681386066),
#  ('Veigar', 0.4026091608708177),
#  ('Morgana', 0.24119067894531906),
#  ('Neeko', 0.20571280236287026),
#  ('Galio', 0.13886927920427242)]
# Recommendation: HpXI4tMjKDx3ySSN0fXBYBh3zqtvEW2xDgQG6eKyamQN9k9F
# [('Brand', 0.3195094214196587),
#  ('Veigar', 0.19579348701574864),
#  ('Lux', 0.14535210188073594),
#  ('Morgana', 0.11567376282785465),
#  ('Neeko', 0.08685701186483419),
#  ('Xerath', 0.07759689443529047),
#  ('Zyra', 0.07640704416547348),
#  ('MissFortune', 0.06964222324225426),
#  ('Blitzcrank', 0.06890838063159006),
#  ('Ahri', 0.06522486799677427)]
#
# Most played: Ovy0KZGs2bdtLi3fddWlzRFJnQ-3KP2iIuu-1ot78uavttEw
# [('MissFortune', 1.0),
#  ('Ashe', 0.4907798910774882),
#  ('Jhin', 0.1734411754595322),
#  ('Jinx', 0.09594151512621686),
#  ('Samira', 0.05067826935322552),
#  ('Sivir', 0.0481115350806115)]
# Recommendation: Ovy0KZGs2bdtLi3fddWlzRFJnQ-3KP2iIuu-1ot78uavttEw
# [('MissFortune', 0.2814557067004281),
#  ('Ashe', 0.19331670050721073),
#  ('Caitlyn', 0.11549400781844943),
#  ('Jinx', 0.11277622534804628),
#  ('Sivir', 0.11164909882839606),
#  ('Jhin', 0.108391639229628),
#  ('Tristana', 0.08776807064404304),
#  ('Kaisa', 0.07225927615666655),
#  ('Varus', 0.07071267637081481),
#  ('Ezreal', 0.06999840664869848)]

# %%
for i in algo.get_neighbors(trainset.to_inner_iid('Singed'), 10):
    print(trainset.to_raw_iid(i))
# Out:
# Sion
# Shaco
# Gangplank
# Karthus
# Tryndamere
# Kled
# Ivern
# Skarner
# Nasus
# Bard
